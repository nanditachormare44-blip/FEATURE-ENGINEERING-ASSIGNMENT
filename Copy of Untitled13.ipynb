# %% [markdown]
# ###FEATURE ENGENERRING

# %% [markdown]
# **Question 1:What is a parameter?**
#
#             :-A parameter is a variable that defines a model's behaviour ,learned from data during training. For example,in a linear regression model y = mx+c, m(slope) and C(intercept) are parameters.

# %% [markdown]
# **Question 2:What is correlation?**
#
#              :-Correlation measures the strength and direction of a relationship between two variables.For example,a correlation coefficient of 0.8 between study hours and exam scores indicates a strong positive relationship.

# %% [markdown]
# **Question 3:What does negative correlation mean?**
#
#             :-Negative correlation means that as one variable increases, the other decrease.For example,as outdoor temperature rises,the demand for heaters typically decreases.

# %% [markdown]
# **Question 4:Define Machine Learning.What are the main components in Machine Learning ?How does loss value help in determining whether the model is good or not?**
#
#             :-Machine Learning is the process of teaching computers to learn from data and make predictions. Main components include data, model,algorithm, and evaluation metrics. Loss value measures prediction error;a lower loss(e.g;0.1vs1.0 in a regression task) indicates a better model fit.

# %% [markdown]
# **Question 5:What are the continous and catergorical variables?**
#
#             :-Continous variables are numeric and can take any value(e.g,height in meters),while categorical variables represent groups and label (e.g:colour-red,blue).

# %% [markdown]
# **Question 6:How do we handel categorical variables in machine learning? What are the techniques?**
#
#             :-Categorical variables are handled using techniques like one-hot encoding (e.g:"red" to 0),depending on the algoritm.

# %% [markdown]
# **Question 7:What do you mean by training and testing a dataset?**
#
#             :-Training uses a dataset to build a model (e.g;80% of data),while testing evaluates it on unseen data(e.g;20%) to check performance ,like accuracy on a classificaton task.

# %% [markdown]
# **Question 8:What is sklearn.preprocessing?**
#
#             :-sklearn.preprocessing is a module in scikit-learn for data preprocessing e.g; scaling features with StandardScaler() to normalize data between 0 and 1.

# %% [markdown]
# **Question 9:What is test set?**
#
#             :-A test set is a portion of data reserved to evaluate a trained model's performance,e.g:20% of a dataset not used in training.

# %% [markdown]
# **Question 10:How do we split data for model fitting(training and testing) in python?**
#
#              :-Use train_test_split from scikit-learn:from sklearn.model_selection import train_test_split;X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2).

# %% [markdown]
# **Question 11:How do you approach a Machine Learning problem?**
#
#              :-Start with problem definition (e.g;predict house prices),gather data ,preprocess it, select a model(e.g;linear regression),train,evaluate and tune it.

# %% [markdown]
# **Question 12:Why do we have to perform EDA before fitting a model to the data?**
#
#              :-Exploratory Data Analysis (EDA) identifies patterns,outliers, and relationship (e.g;plotting a scatter graph to sspot trends),ensuring better model performance.

# %% [markdown]
# **Question 13:What is correlation?What does negative correlation mean?**
#
#              :-Correlation measures variable relationships(e.g;0.9 between rain and umbrella sales).Negative correlation (e.g;-0.7 between tempreture and jacket sales) means one decreases as the other increases.

# %% [markdown]
# **Question 14:How can you find correlation between variables in python?**
#
#              :-Use pandas:df.corr() to get a correlation matrix,e.g;showing correlation between age and income.

# %% [markdown]
# **Question 15:What is causation?Explain difference between correlation and causation with an example.**
#
#              :-Causation means one variable causes another.Correlation (e.g;ice cream sales and drowning incidents rise together) dosen't imply causation;heat causing both is the casual factor.

# %% [markdown]
# **Question 16:What is an optimizer? What are different types of optimizers?Explain each with an example?**
#
#              :-An optimizer adjusts model parameter to minimize loss.Type include:
#
#              **SGD(STOCHASTIC GRADIENT DESCENT): Updates parameters using one sample at a time(eg;in neutral networks).
#
#              **Adam:Combines momentum and RMSprop, efficient for deep learning(e.g; training a CNN).

# %% [markdown]
# **Question 17:What is sklearn.linear_model?What are different types of optimizers?Explain each with an example.**
#
#              :-sklearn.linear_model provides linear models like LinearRegression. Optimizers aren't directly specified here, but underlying optimization (e.g;ordinary least squares) fits the model. Example: from sklearn.linear_model
#              import LinearRegression; model=LinearRegression().

# %% [markdown]
# **Question 18:What does model.fit() do ?What arguments must be given?**
#
#              :-model.predict() makes predictions on new data.
#              Requires x (features),eg;predictions =model.predict(X_test).

# %% [markdown]
# **Question 19:What does model.predict() do?What arguments must be given?**
#
#              :-model.predict() makes predictions on new data.
#                Requires X(features),eg:predictions = model.predict(X_test).

# %% [markdown]
# **Question 20:What are continous and categorical variables?**
#
#              :-Continous variables are numeric and can take any value (e.g;height in meters),while categorical variables represent groups(e.g;colour:red,blue).

# %% [markdown]
# **Question 21:What is feature scaling ?How does it help in Machine Learning?**
#
#              :-Feature scaling normalizes data to a common range (e.g;0 to 1).It helps algorithms like SVM converge faster,e.g;scaling age (0-100) and income (0-100000) for better performance.

# %% [markdown]
# **Question 22:How do we perform scaling in python?**
#
#              :-Use StandardScaler from scikit -learn
#              from skleaarn.preprocessinng import StandardScaler;
#              scaler = StandardScaler()
#              X_scaled =scaler.
#              fit_transform(X).

# %% [markdown]
# **Question 23:What is sklearn.preprocessing?**
#
#              :-sklearn.preprocessing is a module for data preprocessing ,eg;scaling with StandardScaler() or encoding with OneHotEncoder().

# %% [markdown]
# **Question 24:How do we split data for model fitting(training and testing) in python?**
#
#              :-train_test_split:
#              from sklearn.model_selection import
#              train_test_split
#              X_train,X_test,y_train,y_test =train_test_split(X,y,test_size=0.2)

# %% [markdown]
# **Question 25:Explain data encoding?**
#
#              :-Data encoding converts categorial data into numeric from for models.Example: One-hot encoding truns "colour:red" into[1,0,0] using OneHotEncoder in python.
